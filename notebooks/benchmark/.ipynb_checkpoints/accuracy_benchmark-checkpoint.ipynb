# %%
# %run ../../main.py

# %%
from cba.algorithms import top_rules
from cba.data_structures import TransactionDB, Consequent, Antecedent, Item, ClassAssocationRule
from cba.algorithms import M1Algorithm, M2Algorithm, createCARs
import pandas as pd
from sklearn.metrics import accuracy_score

directory = "c:/code/python/machine_learning/assoc_rules"

def func(datasetname, unique_transactions=True):
    pd_ds = pd.read_csv("c:/code/python/machine_learning/assoc_rules/train/{}.csv".format(datasetname))
    txns = TransactionDB.from_DataFrame(pd_ds, unique_transactions=unique_transactions)
    
    txns_test = TransactionDB.from_DataFrame(pd.read_csv("c:/code/python/machine_learning/assoc_rules/test/{}.csv".format(datasetname)))

    rules = top_rules(txns.string_representation, appearance=txns.appeardict)

    rules.sort(reverse=True)


    cars = createCARs(rules)

    cars.sort(reverse=True)

    if len(cars) > 1000:
        cars = cars[:1000]
        

    print("len(rules)", len(cars))

    m1 = M1Algorithm(cars, txns)
    
    m2 = M2Algorithm(cars, txns)
    
    m1clf = m1.build()
    m2clf = m2.build()
    
    
    actual = list(map(lambda i: i.value, txns_test.class_labels))

    pred = m1clf.predict_all(txns_test)
    predM2 = m2clf.predict_all(txns_test)
    
    accM2 = accuracy_score(predM2, actual)
    acc = accuracy_score(pred, actual)

    return acc, accM2



def mean_func(dataset_name, start=0, end=10):
    files = [ dataset_name + repr(i) for i in range(start, end) ]

    accs = []
    accsM2 = []
    
    for file in files:
        acc, accM2 = func(file)
        print("done", file, acc)
        print("done m2", file, accM2)
        accs.append(acc)
        accsM2.append(accM2)
        
    mn = sum(accs) / len(accs)
    mnM2 = sum(accsM2) / len(accsM2)
    
    return mn, mnM2


                
datasets = [
    "iris",
    "breast-w",
    "anneal",
    "hypothyroid",
    "ionosphere",
    "lymph",
    "vehicle",
    "autos",
    "diabetes",
    "glass",
    "heart-h",
    "tic-tac-toe",
    "australian",
    "sick",
    "segment",
    "spambase",
    "sonar",
    "vowel",
    "hepatitis",
    "credit-a",
    "mushroom",
    "house-votes-84",
    "soybean",
    "primary-tumor",
    "credit-g",
    "audiology",
    "breast-cancer",
    "balance-scale",
    "heart-c",
    "kr-vs-kp",
    "pima",
    "heart-statlog"]    

means = []
meansM2 = []
for dataset in datasets:
    acc, accM2 = mean_func(dataset)
    print("*****")
    print("M1", dataset, acc)
    print("M2", dataset, accM2)
    print("******")
    
    means.append((dataset, acc))
    meansM2.append((dataset, accM2))
    
print("M1")
print(means)
print("\nM2")
print(meansM2)
# Out:
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=5
# Rule count: 96, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=5
# Rule count: 166, Iteration: 2
# Increasing maxlen 5
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 190, Iteration: 3
# Decreasing confidence to 0.45
# Running apriori with setting: confidence=0.45, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 190, Iteration: 4
# Decreasing confidence to 0.4
# Running apriori with setting: confidence=0.4, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 190, Iteration: 5
# Decreasing confidence to 0.35000000000000003
# Running apriori with setting: confidence=0.35000000000000003, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 190, Iteration: 6
# Decreasing confidence to 0.30000000000000004
# Running apriori with setting: confidence=0.30000000000000004, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 190, Iteration: 7
# Decreasing confidence to 0.25000000000000006
# Running apriori with setting: confidence=0.25000000000000006, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 190, Iteration: 8
# Decreasing confidence to 0.20000000000000007
# Running apriori with setting: confidence=0.20000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 190, Iteration: 9
# Decreasing confidence to 0.15000000000000008
# Running apriori with setting: confidence=0.15000000000000008, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 190, Iteration: 10
# Decreasing confidence to 0.10000000000000007
# Running apriori with setting: confidence=0.10000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 190, Iteration: 11
# Decreasing confidence to 0.05000000000000007
# Running apriori with setting: confidence=0.05000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 190, Iteration: 12
# Decreasing confidence to 6.938893903907228e-17
# Running apriori with setting: confidence=6.938893903907228e-17, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 190, Iteration: 13
# All options exhausted
# len(rules) 190
# done iris0 1.0
# done m2 iris0 1.0
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=5
# Rule count: 83, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=5
# Rule count: 140, Iteration: 2
# Increasing maxlen 5
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 159, Iteration: 3
# Decreasing confidence to 0.45
# Running apriori with setting: confidence=0.45, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 159, Iteration: 4
# Decreasing confidence to 0.4
# Running apriori with setting: confidence=0.4, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 159, Iteration: 5
# Decreasing confidence to 0.35000000000000003
# Running apriori with setting: confidence=0.35000000000000003, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 159, Iteration: 6
# Decreasing confidence to 0.30000000000000004
# Running apriori with setting: confidence=0.30000000000000004, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 159, Iteration: 7
# Decreasing confidence to 0.25000000000000006
# Running apriori with setting: confidence=0.25000000000000006, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 159, Iteration: 8
# Decreasing confidence to 0.20000000000000007
# Running apriori with setting: confidence=0.20000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 159, Iteration: 9
# Decreasing confidence to 0.15000000000000008
# Running apriori with setting: confidence=0.15000000000000008, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 159, Iteration: 10
# Decreasing confidence to 0.10000000000000007
# Running apriori with setting: confidence=0.10000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 159, Iteration: 11
# Decreasing confidence to 0.05000000000000007
# Running apriori with setting: confidence=0.05000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 159, Iteration: 12
# Decreasing confidence to 6.938893903907228e-17
# Running apriori with setting: confidence=6.938893903907228e-17, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 159, Iteration: 13
# All options exhausted
# len(rules) 159
# done iris1 0.933333333333
# done m2 iris1 0.933333333333
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=5
# Rule count: 72, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=5
# Rule count: 118, Iteration: 2
# Increasing maxlen 5
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 133, Iteration: 3
# Decreasing confidence to 0.45
# Running apriori with setting: confidence=0.45, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 133, Iteration: 4
# Decreasing confidence to 0.4
# Running apriori with setting: confidence=0.4, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 133, Iteration: 5
# Decreasing confidence to 0.35000000000000003
# Running apriori with setting: confidence=0.35000000000000003, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 133, Iteration: 6
# Decreasing confidence to 0.30000000000000004
# Running apriori with setting: confidence=0.30000000000000004, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 133, Iteration: 7
# Decreasing confidence to 0.25000000000000006
# Running apriori with setting: confidence=0.25000000000000006, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 133, Iteration: 8
# Decreasing confidence to 0.20000000000000007
# Running apriori with setting: confidence=0.20000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 133, Iteration: 9
# Decreasing confidence to 0.15000000000000008
# Running apriori with setting: confidence=0.15000000000000008, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 133, Iteration: 10
# Decreasing confidence to 0.10000000000000007
# Running apriori with setting: confidence=0.10000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 133, Iteration: 11
# Decreasing confidence to 0.05000000000000007
# Running apriori with setting: confidence=0.05000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 133, Iteration: 12
# Decreasing confidence to 6.938893903907228e-17
# Running apriori with setting: confidence=6.938893903907228e-17, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 133, Iteration: 13
# All options exhausted
# len(rules) 133
# done iris2 0.933333333333
# done m2 iris2 0.933333333333
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=5
# Rule count: 71, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=5
# Rule count: 114, Iteration: 2
# Increasing maxlen 5
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 127, Iteration: 3
# Decreasing confidence to 0.45
# Running apriori with setting: confidence=0.45, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 127, Iteration: 4
# Decreasing confidence to 0.4
# Running apriori with setting: confidence=0.4, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 127, Iteration: 5
# Decreasing confidence to 0.35000000000000003
# Running apriori with setting: confidence=0.35000000000000003, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 127, Iteration: 6
# Decreasing confidence to 0.30000000000000004
# Running apriori with setting: confidence=0.30000000000000004, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 127, Iteration: 7
# Decreasing confidence to 0.25000000000000006
# Running apriori with setting: confidence=0.25000000000000006, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 127, Iteration: 8
# Decreasing confidence to 0.20000000000000007
# Running apriori with setting: confidence=0.20000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 127, Iteration: 9
# Decreasing confidence to 0.15000000000000008
# Running apriori with setting: confidence=0.15000000000000008, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 127, Iteration: 10
# Decreasing confidence to 0.10000000000000007
# Running apriori with setting: confidence=0.10000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 127, Iteration: 11
# Decreasing confidence to 0.05000000000000007
# Running apriori with setting: confidence=0.05000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 127, Iteration: 12
# Decreasing confidence to 6.938893903907228e-17
# Running apriori with setting: confidence=6.938893903907228e-17, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 127, Iteration: 13
# All options exhausted
# len(rules) 127
# done iris3 0.933333333333
# done m2 iris3 0.933333333333
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=5
# Rule count: 79, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=5
# Rule count: 129, Iteration: 2
# Increasing maxlen 5
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 145, Iteration: 3
# Decreasing confidence to 0.45
# Running apriori with setting: confidence=0.45, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 145, Iteration: 4
# Decreasing confidence to 0.4
# Running apriori with setting: confidence=0.4, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 145, Iteration: 5
# Decreasing confidence to 0.35000000000000003
# Running apriori with setting: confidence=0.35000000000000003, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 145, Iteration: 6
# Decreasing confidence to 0.30000000000000004
# Running apriori with setting: confidence=0.30000000000000004, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 145, Iteration: 7
# Decreasing confidence to 0.25000000000000006
# Running apriori with setting: confidence=0.25000000000000006, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 145, Iteration: 8
# Decreasing confidence to 0.20000000000000007
# Running apriori with setting: confidence=0.20000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 145, Iteration: 9
# Decreasing confidence to 0.15000000000000008
# Running apriori with setting: confidence=0.15000000000000008, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 145, Iteration: 10
# Decreasing confidence to 0.10000000000000007
# Running apriori with setting: confidence=0.10000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 145, Iteration: 11
# Decreasing confidence to 0.05000000000000007
# Running apriori with setting: confidence=0.05000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 145, Iteration: 12
# Decreasing confidence to 6.938893903907228e-17
# Running apriori with setting: confidence=6.938893903907228e-17, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 145, Iteration: 13
# All options exhausted
# len(rules) 145
# done iris4 1.0
# done m2 iris4 1.0
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=5
# Rule count: 66, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=5
# Rule count: 105, Iteration: 2
# Increasing maxlen 5
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 117, Iteration: 3
# Decreasing confidence to 0.45
# Running apriori with setting: confidence=0.45, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 117, Iteration: 4
# Decreasing confidence to 0.4
# Running apriori with setting: confidence=0.4, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 117, Iteration: 5
# Decreasing confidence to 0.35000000000000003
# Running apriori with setting: confidence=0.35000000000000003, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 117, Iteration: 6
# Decreasing confidence to 0.30000000000000004
# Running apriori with setting: confidence=0.30000000000000004, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 117, Iteration: 7
# Decreasing confidence to 0.25000000000000006
# Running apriori with setting: confidence=0.25000000000000006, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 117, Iteration: 8
# Decreasing confidence to 0.20000000000000007
# Running apriori with setting: confidence=0.20000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 117, Iteration: 9
# Decreasing confidence to 0.15000000000000008
# Running apriori with setting: confidence=0.15000000000000008, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 117, Iteration: 10
# Decreasing confidence to 0.10000000000000007
# Running apriori with setting: confidence=0.10000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 117, Iteration: 11
# Decreasing confidence to 0.05000000000000007
# Running apriori with setting: confidence=0.05000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 117, Iteration: 12
# Decreasing confidence to 6.938893903907228e-17
# Running apriori with setting: confidence=6.938893903907228e-17, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 117, Iteration: 13
# All options exhausted
# len(rules) 117
# done iris5 0.866666666667
# done m2 iris5 0.866666666667
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=5
# Rule count: 69, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=5
# Rule count: 109, Iteration: 2
# Increasing maxlen 5
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 121, Iteration: 3
# Decreasing confidence to 0.45
# Running apriori with setting: confidence=0.45, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 121, Iteration: 4
# Decreasing confidence to 0.4
# Running apriori with setting: confidence=0.4, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 121, Iteration: 5
# Decreasing confidence to 0.35000000000000003
# Running apriori with setting: confidence=0.35000000000000003, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 121, Iteration: 6
# Decreasing confidence to 0.30000000000000004
# Running apriori with setting: confidence=0.30000000000000004, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 121, Iteration: 7
# Decreasing confidence to 0.25000000000000006
# Running apriori with setting: confidence=0.25000000000000006, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 121, Iteration: 8
# Decreasing confidence to 0.20000000000000007
# Running apriori with setting: confidence=0.20000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 121, Iteration: 9
# Decreasing confidence to 0.15000000000000008
# Running apriori with setting: confidence=0.15000000000000008, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 121, Iteration: 10
# Decreasing confidence to 0.10000000000000007
# Running apriori with setting: confidence=0.10000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 121, Iteration: 11
# Decreasing confidence to 0.05000000000000007
# Running apriori with setting: confidence=0.05000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 121, Iteration: 12
# Decreasing confidence to 6.938893903907228e-17
# Running apriori with setting: confidence=6.938893903907228e-17, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 121, Iteration: 13
# All options exhausted
# len(rules) 121
# done iris6 0.933333333333
# done m2 iris6 0.933333333333
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=5
# Rule count: 81, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=5
# Rule count: 135, Iteration: 2
# Increasing maxlen 5
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 3
# Decreasing confidence to 0.45
# Running apriori with setting: confidence=0.45, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 4
# Decreasing confidence to 0.4
# Running apriori with setting: confidence=0.4, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 5
# Decreasing confidence to 0.35000000000000003
# Running apriori with setting: confidence=0.35000000000000003, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 6
# Decreasing confidence to 0.30000000000000004
# Running apriori with setting: confidence=0.30000000000000004, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 7
# Decreasing confidence to 0.25000000000000006
# Running apriori with setting: confidence=0.25000000000000006, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 8
# Decreasing confidence to 0.20000000000000007
# Running apriori with setting: confidence=0.20000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 9
# Decreasing confidence to 0.15000000000000008
# Running apriori with setting: confidence=0.15000000000000008, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 10
# Decreasing confidence to 0.10000000000000007
# Running apriori with setting: confidence=0.10000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 11
# Decreasing confidence to 0.05000000000000007
# Running apriori with setting: confidence=0.05000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 12
# Decreasing confidence to 6.938893903907228e-17
# Running apriori with setting: confidence=6.938893903907228e-17, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 13
# All options exhausted
# len(rules) 153
# done iris7 1.0
# done m2 iris7 1.0
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=5
# Rule count: 84, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=5
# Rule count: 139, Iteration: 2
# Increasing maxlen 5
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 157, Iteration: 3
# Decreasing confidence to 0.45
# Running apriori with setting: confidence=0.45, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 157, Iteration: 4
# Decreasing confidence to 0.4
# Running apriori with setting: confidence=0.4, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 157, Iteration: 5
# Decreasing confidence to 0.35000000000000003
# Running apriori with setting: confidence=0.35000000000000003, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 157, Iteration: 6
# Decreasing confidence to 0.30000000000000004
# Running apriori with setting: confidence=0.30000000000000004, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 157, Iteration: 7
# Decreasing confidence to 0.25000000000000006
# Running apriori with setting: confidence=0.25000000000000006, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 157, Iteration: 8
# Decreasing confidence to 0.20000000000000007
# Running apriori with setting: confidence=0.20000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 157, Iteration: 9
# Decreasing confidence to 0.15000000000000008
# Running apriori with setting: confidence=0.15000000000000008, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 157, Iteration: 10
# Decreasing confidence to 0.10000000000000007
# Running apriori with setting: confidence=0.10000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 157, Iteration: 11
# Decreasing confidence to 0.05000000000000007
# Running apriori with setting: confidence=0.05000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 157, Iteration: 12
# Decreasing confidence to 6.938893903907228e-17
# Running apriori with setting: confidence=6.938893903907228e-17, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 157, Iteration: 13
# All options exhausted
# len(rules) 157
# done iris8 1.0
# done m2 iris8 1.0
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=5
# Rule count: 83, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=5
# Rule count: 136, Iteration: 2
# Increasing maxlen 5
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 3
# Decreasing confidence to 0.45
# Running apriori with setting: confidence=0.45, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 4
# Decreasing confidence to 0.4
# Running apriori with setting: confidence=0.4, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 5
# Decreasing confidence to 0.35000000000000003
# Running apriori with setting: confidence=0.35000000000000003, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 6
# Decreasing confidence to 0.30000000000000004
# Running apriori with setting: confidence=0.30000000000000004, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 7
# Decreasing confidence to 0.25000000000000006
# Running apriori with setting: confidence=0.25000000000000006, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 8
# Decreasing confidence to 0.20000000000000007
# Running apriori with setting: confidence=0.20000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 9
# Decreasing confidence to 0.15000000000000008
# Running apriori with setting: confidence=0.15000000000000008, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 10
# Decreasing confidence to 0.10000000000000007
# Running apriori with setting: confidence=0.10000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 11
# Decreasing confidence to 0.05000000000000007
# Running apriori with setting: confidence=0.05000000000000007, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 12
# Decreasing confidence to 6.938893903907228e-17
# Running apriori with setting: confidence=6.938893903907228e-17, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=5
# Rule count: 153, Iteration: 13
# All options exhausted
# len(rules) 153
# done iris9 0.866666666667
# done m2 iris9 0.866666666667
# *****
# M1 iris 0.946666666667
# M2 iris 0.946666666667
# ******
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=10
# Rule count: 702, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=10
# Rule count: 4185, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done breast-w0 0.943661971831
# done m2 breast-w0 0.943661971831
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=10
# Rule count: 718, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=10
# Rule count: 4303, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done breast-w1 0.957142857143
# done m2 breast-w1 0.957142857143
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=10
# Rule count: 741, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=10
# Rule count: 4474, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done breast-w2 0.957142857143
# done m2 breast-w2 0.957142857143
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=10
# Rule count: 683, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=10
# Rule count: 4056, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done breast-w3 0.9
# done m2 breast-w3 0.9
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=10
# Rule count: 708, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=10
# Rule count: 4241, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done breast-w4 0.971428571429
# done m2 breast-w4 0.971428571429
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=10
# Rule count: 639, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=10
# Rule count: 3718, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done breast-w5 0.957142857143
# done m2 breast-w5 0.957142857143
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=10
# Rule count: 688, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=10
# Rule count: 4100, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done breast-w6 0.957142857143
# done m2 breast-w6 0.957142857143
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=10
# Rule count: 682, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=10
# Rule count: 4061, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done breast-w7 0.985714285714
# done m2 breast-w7 0.985714285714
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=10
# Rule count: 685, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=10
# Rule count: 4083, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done breast-w8 0.942028985507
# done m2 breast-w8 0.942028985507
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=10
# Rule count: 725, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=10
# Rule count: 4345, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done breast-w9 0.942028985507
# done m2 breast-w9 0.942028985507
# *****
# M1 breast-w 0.951343422856
# M2 breast-w 0.951343422856
# ******
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=33
# Rule count: 6309, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done anneal0 1.0
# done m2 anneal0 1.0
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=33
# Rule count: 6951, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done anneal1 1.0
# done m2 anneal1 1.0
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=33
# Rule count: 6535, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done anneal2 1.0
# done m2 anneal2 1.0
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=33
# Rule count: 6821, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done anneal3 0.989010989011
# done m2 anneal3 0.989010989011
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=33
# Rule count: 6745, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done anneal4 0.988888888889
# done m2 anneal4 0.988888888889
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=33
# Rule count: 6693, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done anneal5 0.988888888889
# done m2 anneal5 0.988888888889
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=33
# Rule count: 6833, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done anneal6 0.988888888889
# done m2 anneal6 0.988888888889
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=33
# Rule count: 6766, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done anneal7 0.966292134831
# done m2 anneal7 0.966292134831
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=32
# Rule count: 6576, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done anneal8 1.0
# done m2 anneal8 1.0
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=33
# Rule count: 6326, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done anneal9 0.988636363636
# done m2 anneal9 0.988636363636
# *****
# M1 anneal 0.991060615415
# M2 anneal 0.991060615415
# ******
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=29
# Rule count: 4444, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done hypothyroid0 0.984168865435
# done m2 hypothyroid0 0.984168865435
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=29
# Rule count: 4335, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done hypothyroid1 0.978835978836
# done m2 hypothyroid1 0.978835978836
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=29
# Rule count: 4306, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done hypothyroid2 0.98944591029
# done m2 hypothyroid2 0.98944591029
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=29
# Rule count: 4409, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done hypothyroid3 0.978835978836
# done m2 hypothyroid3 0.978835978836
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=29
# Rule count: 4342, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done hypothyroid4 0.981432360743
# done m2 hypothyroid4 0.981432360743
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=29
# Rule count: 4338, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done hypothyroid5 0.994680851064
# done m2 hypothyroid5 0.994680851064
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=29
# Rule count: 4413, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done hypothyroid6 0.989361702128
# done m2 hypothyroid6 0.989361702128
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=29
# Rule count: 4170, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done hypothyroid7 0.981432360743
# done m2 hypothyroid7 0.981432360743
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=29
# Rule count: 4301, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done hypothyroid8 0.989361702128
# done m2 hypothyroid8 0.989361702128
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=29
# Rule count: 4497, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done hypothyroid9 0.989361702128
# done m2 hypothyroid9 0.989361702128
# *****
# M1 hypothyroid 0.985691741233
# M2 hypothyroid 0.985691741233
# ******
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=35
# Rule count: 11176, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done ionosphere0 0.916666666667
# done m2 ionosphere0 0.916666666667
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=35
# Rule count: 12443, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done ionosphere1 0.916666666667
# done m2 ionosphere1 0.916666666667
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=35
# Rule count: 11668, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done ionosphere2 0.972222222222
# done m2 ionosphere2 0.972222222222
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=35
# Rule count: 12162, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done ionosphere3 0.972222222222
# done m2 ionosphere3 0.972222222222
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=35
# Rule count: 12300, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done ionosphere4 0.916666666667
# done m2 ionosphere4 0.916666666667
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=35
# Rule count: 12765, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done ionosphere5 0.971428571429
# done m2 ionosphere5 0.971428571429
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=35
# Rule count: 12545, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done ionosphere6 0.911764705882
# done m2 ionosphere6 0.911764705882
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=35
# Rule count: 11563, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done ionosphere7 0.911764705882
# done m2 ionosphere7 0.911764705882
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=35
# Rule count: 12566, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done ionosphere8 0.882352941176
# done m2 ionosphere8 0.882352941176
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=35
# Rule count: 12289, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done ionosphere9 0.882352941176
# done m2 ionosphere9 0.882352941176
# *****
# M1 ionosphere 0.925410830999
# M2 ionosphere 0.925410830999
# ******
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done lymph0 0.888888888889
# done m2 lymph0 0.888888888889
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2365, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done lymph1 0.714285714286
# done m2 lymph1 0.714285714286
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2353, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done lymph2 0.785714285714
# done m2 lymph2 0.785714285714
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2393, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done lymph3 0.714285714286
# done m2 lymph3 0.714285714286
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2233, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done lymph4 0.733333333333
# done m2 lymph4 0.733333333333
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2405, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done lymph5 0.928571428571
# done m2 lymph5 0.928571428571
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2385, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done lymph6 0.785714285714
# done m2 lymph6 0.785714285714
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2333, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done lymph7 0.8
# done m2 lymph7 0.8
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2246, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done lymph8 0.75
# done m2 lymph8 0.75
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2404, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done lymph9 0.785714285714
# done m2 lymph9 0.785714285714
# *****
# M1 lymph 0.788650793651
# M2 lymph 0.788650793651
# ******
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 5461, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done vehicle0 0.709302325581
# done m2 vehicle0 0.709302325581
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 5227, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done vehicle1 0.662790697674
# done m2 vehicle1 0.662790697674
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 5761, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done vehicle2 0.717647058824
# done m2 vehicle2 0.717647058824
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 5490, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done vehicle3 0.741176470588
# done m2 vehicle3 0.741176470588
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 5542, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done vehicle4 0.647058823529
# done m2 vehicle4 0.647058823529
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 5108, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done vehicle5 0.694117647059
# done m2 vehicle5 0.694117647059
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 5307, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done vehicle6 0.717647058824
# done m2 vehicle6 0.717647058824
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 5621, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done vehicle7 0.654761904762
# done m2 vehicle7 0.595238095238
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 4911, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done vehicle8 0.650602409639
# done m2 vehicle8 0.650602409639
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 5255, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done vehicle9 0.646341463415
# done m2 vehicle9 0.646341463415
# *****
# M1 vehicle 0.684144585989
# M2 vehicle 0.678192205037
# ******
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=26
# Rule count: 8294, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done autos0 0.875
# done m2 autos0 0.875
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=26
# Rule count: 7996, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done autos1 0.739130434783
# done m2 autos1 0.739130434783
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=26
# Rule count: 8016, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done autos2 0.761904761905
# done m2 autos2 0.761904761905
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=26
# Rule count: 8243, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done autos3 0.857142857143
# done m2 autos3 0.857142857143
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=26
# Rule count: 7915, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done autos4 0.809523809524
# done m2 autos4 0.809523809524
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=26
# Rule count: 7944, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done autos5 0.85
# done m2 autos5 0.85
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=26
# Rule count: 8245, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done autos6 0.75
# done m2 autos6 0.75
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=26
# Rule count: 7987, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done autos7 1.0
# done m2 autos7 1.0
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=26
# Rule count: 7920, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done autos8 0.842105263158
# done m2 autos8 0.842105263158
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=26
# Rule count: 8066, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done autos9 0.611111111111
# done m2 autos9 0.611111111111
# *****
# M1 autos 0.809591823762
# M2 autos 0.809591823762
# ******
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=9
# Rule count: 307, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=9
# Rule count: 1376, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done diabetes0 0.753246753247
# done m2 diabetes0 0.753246753247
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=9
# Rule count: 274, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=9
# Rule count: 1167, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done diabetes1 0.766233766234
# done m2 diabetes1 0.766233766234
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=9
# Rule count: 275, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=9
# Rule count: 1171, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done diabetes2 0.688311688312
# done m2 diabetes2 0.688311688312
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=9
# Rule count: 275, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=9
# Rule count: 1167, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done diabetes3 0.766233766234
# done m2 diabetes3 0.766233766234
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=9
# Rule count: 220, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=9
# Rule count: 870, Iteration: 2
# Increasing maxlen 5
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=9
# Rule count: 2182, Iteration: 3
# Target rule count satisfied: 1000
# len(rules) 1000
# done diabetes4 0.753246753247
# done m2 diabetes4 0.753246753247
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=9
# Rule count: 277, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=9
# Rule count: 1208, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done diabetes5 0.753246753247
# done m2 diabetes5 0.753246753247
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=9
# Rule count: 314, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=9
# Rule count: 1477, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done diabetes6 0.662337662338
# done m2 diabetes6 0.662337662338
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=9
# Rule count: 279, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=9
# Rule count: 1236, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done diabetes7 0.753246753247
# done m2 diabetes7 0.753246753247
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=9
# Rule count: 274, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=9
# Rule count: 1162, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done diabetes8 0.723684210526
# done m2 diabetes8 0.723684210526
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=9
# Rule count: 279, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=9
# Rule count: 1234, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done diabetes9 0.815789473684
# done m2 diabetes9 0.815789473684
# *****
# M1 diabetes 0.743557758031
# M2 diabetes 0.743557758031
# ******
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=10
# Rule count: 729, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=10
# Rule count: 2790, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done glass0 0.565217391304
# done m2 glass0 0.565217391304
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=10
# Rule count: 707, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=10
# Rule count: 2649, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done glass1 0.695652173913
# done m2 glass1 0.695652173913
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=10
# Rule count: 690, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=10
# Rule count: 2597, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done glass2 0.608695652174
# done m2 glass2 0.565217391304
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=10
# Rule count: 777, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=10
# Rule count: 2990, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done glass3 0.727272727273
# done m2 glass3 0.727272727273
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=10
# Rule count: 725, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=10
# Rule count: 2755, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done glass4 0.636363636364
# done m2 glass4 0.590909090909
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=10
# Rule count: 710, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=10
# Rule count: 2708, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done glass5 0.772727272727
# done m2 glass5 0.772727272727
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=10
# Rule count: 736, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=10
# Rule count: 2844, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done glass6 0.714285714286
# done m2 glass6 0.714285714286
# ...
# Rule count: 817, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=14
# Rule count: 6128, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done heart-c1 0.677419354839
# done m2 heart-c1 0.677419354839
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=14
# Rule count: 814, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=14
# Rule count: 6113, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done heart-c2 0.774193548387
# done m2 heart-c2 0.774193548387
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=14
# Rule count: 819, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=14
# Rule count: 6141, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done heart-c3 0.838709677419
# done m2 heart-c3 0.838709677419
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=14
# Rule count: 780, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=14
# Rule count: 5908, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done heart-c4 0.806451612903
# done m2 heart-c4 0.774193548387
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=14
# Rule count: 819, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=14
# Rule count: 6169, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done heart-c5 0.733333333333
# done m2 heart-c5 0.733333333333
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=14
# Rule count: 816, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=14
# Rule count: 6128, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done heart-c6 0.833333333333
# done m2 heart-c6 0.833333333333
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=14
# Rule count: 872, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=14
# Rule count: 6674, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done heart-c7 0.9
# done m2 heart-c7 0.9
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=14
# Rule count: 818, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=14
# Rule count: 6145, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done heart-c8 0.793103448276
# done m2 heart-c8 0.793103448276
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=14
# Rule count: 821, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=14
# Rule count: 6169, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done heart-c9 0.862068965517
# done m2 heart-c9 0.862068965517
# *****
# M1 heart-c 0.815409714498
# M2 heart-c 0.812183908046
# ******
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=37
# Rule count: 4759, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done kr-vs-kp0 0.925
# done m2 kr-vs-kp0 0.925
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=37
# Rule count: 4729, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done kr-vs-kp1 0.95625
# done m2 kr-vs-kp1 0.95625
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=37
# Rule count: 4762, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done kr-vs-kp2 0.971875
# done m2 kr-vs-kp2 0.971875
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=37
# Rule count: 4764, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done kr-vs-kp3 0.9375
# done m2 kr-vs-kp3 0.9375
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=37
# Rule count: 4765, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done kr-vs-kp4 0.94375
# done m2 kr-vs-kp4 0.94375
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=37
# Rule count: 4765, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done kr-vs-kp5 0.91875
# done m2 kr-vs-kp5 0.91875
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=37
# Rule count: 4760, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done kr-vs-kp6 0.965625
# done m2 kr-vs-kp6 0.965625
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=37
# Rule count: 4763, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done kr-vs-kp7 0.965517241379
# done m2 kr-vs-kp7 0.965517241379
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=37
# Rule count: 4764, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done kr-vs-kp8 0.94670846395
# done m2 kr-vs-kp8 0.94670846395
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=37
# Rule count: 4752, Iteration: 1
# Target rule count satisfied: 1000
# len(rules) 1000
# done kr-vs-kp9 0.977987421384
# done m2 kr-vs-kp9 0.977987421384
# *****
# M1 kr-vs-kp 0.950896312671
# M2 kr-vs-kp 0.950896312671
# ******
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=9
# Rule count: 307, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=9
# Rule count: 1376, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done pima0 0.753246753247
# done m2 pima0 0.753246753247
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=9
# Rule count: 274, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=9
# Rule count: 1167, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done pima1 0.766233766234
# done m2 pima1 0.766233766234
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=9
# Rule count: 275, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=9
# Rule count: 1171, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done pima2 0.688311688312
# done m2 pima2 0.688311688312
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=9
# Rule count: 275, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=9
# Rule count: 1167, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done pima3 0.766233766234
# done m2 pima3 0.766233766234
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=9
# Rule count: 220, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=9
# Rule count: 870, Iteration: 2
# Increasing maxlen 5
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=5, MAX_RULE_LEN=9
# Rule count: 2182, Iteration: 3
# Target rule count satisfied: 1000
# len(rules) 1000
# done pima4 0.753246753247
# done m2 pima4 0.753246753247
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=9
# Rule count: 277, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=9
# Rule count: 1208, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done pima5 0.753246753247
# done m2 pima5 0.753246753247
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=9
# Rule count: 314, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=9
# Rule count: 1477, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done pima6 0.662337662338
# done m2 pima6 0.662337662338
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=9
# Rule count: 279, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=9
# Rule count: 1236, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done pima7 0.753246753247
# done m2 pima7 0.753246753247
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=9
# Rule count: 274, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=9
# Rule count: 1162, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done pima8 0.723684210526
# done m2 pima8 0.723684210526
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=9
# Rule count: 279, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=9
# Rule count: 1234, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done pima9 0.815789473684
# done m2 pima9 0.815789473684
# *****
# M1 pima 0.743557758031
# M2 pima 0.743557758031
# ******
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=14
# Rule count: 488, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=14
# Rule count: 3177, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done heart-statlog0 0.777777777778
# done m2 heart-statlog0 0.740740740741
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=14
# Rule count: 446, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=14
# Rule count: 2782, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done heart-statlog1 0.888888888889
# done m2 heart-statlog1 0.888888888889
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=14
# Rule count: 488, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=14
# Rule count: 3168, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done heart-statlog2 0.851851851852
# done m2 heart-statlog2 0.814814814815
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=14
# Rule count: 446, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=14
# Rule count: 2783, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done heart-statlog3 0.925925925926
# done m2 heart-statlog3 0.888888888889
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=14
# Rule count: 488, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=14
# Rule count: 3187, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done heart-statlog4 0.814814814815
# done m2 heart-statlog4 0.814814814815
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=14
# Rule count: 446, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=14
# Rule count: 2778, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done heart-statlog5 0.703703703704
# done m2 heart-statlog5 0.740740740741
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=14
# Rule count: 488, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=14
# Rule count: 3173, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done heart-statlog6 0.777777777778
# done m2 heart-statlog6 0.777777777778
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=14
# Rule count: 446, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=14
# Rule count: 2792, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done heart-statlog7 0.888888888889
# done m2 heart-statlog7 0.925925925926
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=14
# Rule count: 446, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=14
# Rule count: 2773, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done heart-statlog8 0.777777777778
# done m2 heart-statlog8 0.777777777778
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=14
# Rule count: 488, Iteration: 1
# Increasing maxlen 4
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=4, MAX_RULE_LEN=14
# Rule count: 3173, Iteration: 2
# Target rule count satisfied: 1000
# len(rules) 1000
# done heart-statlog9 0.851851851852
# done m2 heart-statlog9 0.851851851852
# *****
# M1 heart-statlog 0.825925925926
# M2 heart-statlog 0.822222222222
# ******
# M1
# [('iris', 0.94666666666666666), ('breast-w', 0.95134342285597651), ('anneal', 0.99106061541454804), ('hypothyroid', 0.98569174123297709), ('ionosphere', 0.92541083099906651), ('lymph', 0.7886507936507936), ('vehicle', 0.68414458598944372), ('autos', 0.80959182376230421), ('diabetes', 0.74355775803144231), ('glass', 0.69479923458184323), ('heart-h', 0.65661740558292281), ('tic-tac-toe', 1.0), ('australian', 0.85938131774448911), ('sick', 0.974816458221062), ('segment', 0.89956709956709946), ('spambase', 0.84241978212685731), ('sonar', 0.73132034632034626), ('vowel', 0.67171717171717171), ('hepatitis', 0.79887254901960791), ('credit-a', 0.83194677871148459), ('mushroom', 0.99926184114057892), ('house-votes-84', 0.92640944326990837), ('soybean', 0.80510325977019792), ('primary-tumor', 0.44583891764881473), ('credit-g', 0.7330000000000001), ('audiology', 0.45556345023736328), ('breast-cancer', 0.70670771756978656), ('balance-scale', 0.74080666146239915), ('heart-c', 0.81540971449759003), ('kr-vs-kp', 0.95089631267128039), ('pima', 0.74355775803144231), ('heart-statlog', 0.82592592592592573)]
#
# M2
# [('iris', 0.94666666666666666), ('breast-w', 0.95134342285597651), ('anneal', 0.99106061541454804), ('hypothyroid', 0.98569174123297709), ('ionosphere', 0.92541083099906651), ('lymph', 0.7886507936507936), ('vehicle', 0.67819220503706268), ('autos', 0.80959182376230421), ('diabetes', 0.74355775803144231), ('glass', 0.68090595394943221), ('heart-h', 0.65661740558292281), ('tic-tac-toe', 1.0), ('australian', 0.85938131774448911), ('sick', 0.974816458221062), ('segment', 0.89956709956709946), ('spambase', 0.84241978212685731), ('sonar', 0.74517316017316015), ('vowel', 0.64343434343434347), ('hepatitis', 0.79887254901960791), ('credit-a', 0.83194677871148459), ('mushroom', 0.99926184114057892), ('house-votes-84', 0.92640944326990837), ('soybean', 0.80510325977019792), ('primary-tumor', 0.44271391764881474), ('credit-g', 0.7330000000000001), ('audiology', 0.45991127632431983), ('breast-cancer', 0.70670771756978656), ('balance-scale', 0.73921935987509757), ('heart-c', 0.81218390804597695), ('kr-vs-kp', 0.95089631267128039), ('pima', 0.74355775803144231), ('heart-statlog', 0.82222222222222219)]

# %%
m2df = pd.DataFrame(dict(map(lambda i:  (i[0], [i[1]]), meansM2))).transpose()
m2df.columns = ["m2"]

m1df = pd.DataFrame(dict(map(lambda i:  (i[0], [i[1]]), means))).transpose()
m1df.columns = ["m1"]


acc_df = m1df.join(m2df)

acc_df.to_csv("../data/accuracies.csv")

#acc_df = pd.read_csv("../data/accuracies.csv")

# %%
acc_df
# Out:
#                       m1        m2
# anneal          0.991061  0.991061
# audiology       0.455563  0.459911
# australian      0.859381  0.859381
# autos           0.809592  0.809592
# balance-scale   0.740807  0.739219
# breast-cancer   0.706708  0.706708
# breast-w        0.951343  0.951343
# credit-a        0.831947  0.831947
# credit-g        0.733000  0.733000
# diabetes        0.743558  0.743558
# glass           0.694799  0.680906
# heart-c         0.815410  0.812184
# heart-h         0.656617  0.656617
# heart-statlog   0.825926  0.822222
# hepatitis       0.798873  0.798873
# house-votes-84  0.926409  0.926409
# hypothyroid     0.985692  0.985692
# ionosphere      0.925411  0.925411
# iris            0.946667  0.946667
# kr-vs-kp        0.950896  0.950896
# lymph           0.788651  0.788651
# mushroom        0.999262  0.999262
# pima            0.743558  0.743558
# primary-tumor   0.445839  0.442714
# segment         0.899567  0.899567
# sick            0.974816  0.974816
# sonar           0.731320  0.745173
# soybean         0.805103  0.805103
# spambase        0.842420  0.842420
# tic-tac-toe     1.000000  1.000000
# vehicle         0.684145  0.678192
# vowel           0.671717  0.643434

# %%
ARC_accs = pd.read_csv("../data/arc_accs3.csv")

ARC_accs_mod = ARC_accs[["dataset", "accuracy"]].set_index("dataset")

ARC_accs_mod.columns = ["ARC"]

accs = acc_df.join(ARC_accs_mod)

print("M1", accs["m1"].mean())
print("M2", accs["m2"].mean())
print("ARC", accs["ARC"].mean())
# Out:
# M1 0.8105017932631686
# M2 0.8092027413359664
# ARC 0.7821874999999999

# %%
ARC_accs = pd.read_csv("../data/arc_accs3.csv")

ARC_accs_mod = ARC_accs[["dataset", "accuracy"]].set_index("dataset")

ARC_accs_mod.columns = ["ARC"]

accs = acc_df.join(ARC_accs_mod)

print("M1", accs["m1"].mean())
print("M2", accs["m2"].mean())
print("ARC", accs["ARC"].mean())
# Out:
# M1 0.8105017932631686
# M2 0.8092027413359664
# ARC 0.7821874999999999

# %%
acc_df
# Out:
#                       m1        m2
# anneal          0.991061  0.991061
# audiology       0.455563  0.459911
# australian      0.859381  0.859381
# autos           0.809592  0.809592
# balance-scale   0.740807  0.739219
# breast-cancer   0.706708  0.706708
# breast-w        0.951343  0.951343
# credit-a        0.831947  0.831947
# credit-g        0.733000  0.733000
# diabetes        0.743558  0.743558
# glass           0.694799  0.680906
# heart-c         0.815410  0.812184
# heart-h         0.656617  0.656617
# heart-statlog   0.825926  0.822222
# hepatitis       0.798873  0.798873
# house-votes-84  0.926409  0.926409
# hypothyroid     0.985692  0.985692
# ionosphere      0.925411  0.925411
# iris            0.946667  0.946667
# kr-vs-kp        0.950896  0.950896
# lymph           0.788651  0.788651
# mushroom        0.999262  0.999262
# pima            0.743558  0.743558
# primary-tumor   0.445839  0.442714
# segment         0.899567  0.899567
# sick            0.974816  0.974816
# sonar           0.731320  0.745173
# soybean         0.805103  0.805103
# spambase        0.842420  0.842420
# tic-tac-toe     1.000000  1.000000
# vehicle         0.684145  0.678192
# vowel           0.671717  0.643434

# %%
ARC_accs = pd.read_csv("../data/arc_accs3.csv")

ARC_accs_mod = ARC_accs[["dataset", "accuracy"]].set_index("dataset")

ARC_accs_mod.columns = ["ARC"]

accs = acc_df.join(ARC_accs_mod)

print("M1", accs["m1"].mean())
print("M2", accs["m2"].mean())
print("ARC", accs["ARC"].mean())
# Out:
# M1 0.8105017932631686
# M2 0.8092027413359664
# ARC 0.7821874999999999

# %%
printaccs = accs[["m1", "m2", "ARC"]] * 100
printaccs = printaccs[["m1", "m2", "ARC"]].round(1)

# %%
printaccs.to_csv("../data/all_accuracies.csv")
