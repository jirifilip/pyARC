# %%
# %run ../../main.py
# %matplotlib inline

# %%
import pandas as pd

from cba.algorithms import M1Algorithm, M2Algorithm, top_rules, createCARs 
from cba.data_structures import TransactionDB
import sklearn.metrics as skmetrics

# %%
#
#
# =========================
# Oveření běhu v závislosti na vložených pravidlech / instancích
# =========================
#
#
#

import time

target_rule_count = 50

benchmark_data = {
    "rule_count": [],
    "M1_duration": [],
    "M2_duration": [],
    "M1_accuracy": [],
    "M2_accuracy": [],
    "M1_output_rules": [],
    "M2_output_rules": []
}

number_of_iterations = 10

directory = "c:/code/python/machine_learning/assoc_rules"


for sequence in [*range(10, 20), *range(20, 100, 10), *range(200, 1000, 100), *range(2000, 10000, 1000), *range(20000, 100000, 10000)]:
    target_rule_count = sequence

    dataset_name_benchmark = "lymph0"
    
    pd_ds = pd.read_csv("c:/code/python/machine_learning/assoc_rules/train/{}.csv".format(dataset_name_benchmark))
    pd_ds_test = pd.read_csv("c:/code/python/machine_learning/assoc_rules/test/{}.csv".format(dataset_name_benchmark))
    
    
    txns = TransactionDB.from_DataFrame(pd_ds, unique_transactions=True)
    txns_test = TransactionDB.from_DataFrame(pd_ds_test)
    actual = list(map(lambda i: i.value, txns_test.class_labels))
    
    rules = top_rules(txns.string_representation, appearance=txns.appeardict)

    cars = createCARs(rules)
     
    if len(cars) > target_rule_count:
        cars = cars[:target_rule_count]
        
    

    m1t1 = time.time()
    m1accs = []
    m1rules = []
    for _ in range(number_of_iterations):
        m1 = M1Algorithm(cars, txns)
        clf = m1.build()
        pred = clf.predict_all(txns_test)
        acc = skmetrics.accuracy_score(pred, actual)
        
        m1rules.append(len(clf.rules) + 1)
        m1accs.append(acc)
    
    m1t2 = time.time()
    
    
    m2t1 = time.time()
    m2accs = []
    m2rules = []
    for _ in range(number_of_iterations):
        m2 = M2Algorithm(cars, txns)
        clf = m2.build()
        pred = clf.predict_all(txns_test)
        acc = skmetrics.accuracy_score(pred, actual)
        
        m2rules.append(len(clf.rules) + 1)
        m2accs.append(acc)
        
    
    m2t2 = time.time()
    
     
    m1duration = (m1t2 - m1t1) / number_of_iterations
    m2duration = (m2t2 - m2t1) / number_of_iterations
    m1acc = sum(m1accs) / len(m1accs)
    m2acc = sum(m2accs) / len(m2accs)
    m1rules = sum(m1rules) / number_of_iterations
    m2rules = sum(m2rules) / number_of_iterations
    
    benchmark_data["rule_count"].append(target_rule_count)
    benchmark_data["M1_duration"].append(m1duration)
    benchmark_data["M2_duration"].append(m2duration)
    benchmark_data["M1_accuracy"].append(m1acc)
    benchmark_data["M2_accuracy"].append(m2acc)
    benchmark_data["M1_output_rules"].append(m1rules)
    benchmark_data["M2_output_rules"].append(m2rules)
    
    print("target rule count:", target_rule_count)
    print("M1 duration:", m1duration)
    print("M2 duration:", m2duration)
    print("M1 acc:", m1acc)
    print("M2 acc:", m2acc)
    print("M1 clf len:", m1rules)
    print("M2 clf len:", m2rules)
    
    print("\n\n")
# Out:
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 10
# M1 duration: 0.0019130468368530273
# M2 duration: 0.008464288711547852
# M1 acc: 0.611111111111
# M2 acc: 0.522222222222
# M1 clf len: 10.0
# M2 clf len: 10.0
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 11
# M1 duration: 0.004687643051147461
# M2 duration: 0.013805580139160157
# M1 acc: 0.611111111111
# M2 acc: 0.522222222222
# M1 clf len: 10.0
# M2 clf len: 10.0
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 12
# M1 duration: 0.006902551651000977
# M2 duration: 0.024732017517089845
# M1 acc: 0.611111111111
# M2 acc: 0.522222222222
# M1 clf len: 10.0
# M2 clf len: 10.0
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 13
# M1 duration: 0.003125286102294922
# M2 duration: 0.011590075492858887
# M1 acc: 0.611111111111
# M2 acc: 0.522222222222
# M1 clf len: 11.0
# M2 clf len: 11.0
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 14
# M1 duration: 0.004687356948852539
# M2 duration: 0.02337956428527832
# M1 acc: 0.666666666667
# M2 acc: 0.577777777778
# M1 clf len: 12.0
# M2 clf len: 12.0
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 15
# M1 duration: 0.006249547004699707
# M2 duration: 0.015342187881469727
# M1 acc: 0.666666666667
# M2 acc: 0.577777777778
# M1 clf len: 13.0
# M2 clf len: 13.0
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 16
# M1 duration: 0.0053389549255371095
# M2 duration: 0.014715981483459473
# M1 acc: 0.666666666667
# M2 acc: 0.577777777778
# M1 clf len: 13.0
# M2 clf len: 13.0
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 17
# M1 duration: 0.005291247367858886
# M2 duration: 0.016977787017822266
# M1 acc: 0.722222222222
# M2 acc: 0.633333333333
# M1 clf len: 14.0
# M2 clf len: 14.0
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 18
# M1 duration: 0.0031233310699462892
# M2 duration: 0.010028362274169922
# M1 acc: 0.722222222222
# M2 acc: 0.633333333333
# M1 clf len: 14.0
# M2 clf len: 14.0
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 19
# M1 duration: 0.0017627954483032226
# M2 duration: 0.011592650413513183
# M1 acc: 0.722222222222
# M2 acc: 0.633333333333
# M1 clf len: 14.0
# M2 clf len: 14.0
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 20
# M1 duration: 0.004687857627868652
# M2 duration: 0.01002812385559082
# M1 acc: 0.722222222222
# M2 acc: 0.633333333333
# M1 clf len: 14.0
# M2 clf len: 14.0
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 30
# M1 duration: 0.005341029167175293
# M2 duration: 0.01315169334411621
# M1 acc: 0.722222222222
# M2 acc: 0.677777777778
# M1 clf len: 17.0
# M2 clf len: 17.0
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 40
# M1 duration: 0.006260538101196289
# M2 duration: 0.015367412567138672
# M1 acc: 0.777777777778
# M2 acc: 0.733333333333
# M1 clf len: 18.0
# M2 clf len: 18.0
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 50
# M1 duration: 0.007814383506774903
# M2 duration: 0.022185397148132325
# M1 acc: 0.777777777778
# M2 acc: 0.733333333333
# M1 clf len: 18.0
# M2 clf len: 18.0
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 60
# M1 duration: 0.008464479446411132
# M2 duration: 0.02695462703704834
# M1 acc: 0.777777777778
# M2 acc: 0.733333333333
# M1 clf len: 18.0
# M2 clf len: 18.8
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 70
# M1 duration: 0.008465838432312012
# M2 duration: 0.025325250625610352
# M1 acc: 0.777777777778
# M2 acc: 0.733333333333
# M1 clf len: 18.0
# M2 clf len: 18.8
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 80
# M1 duration: 0.008437395095825195
# M2 duration: 0.026880407333374025
# M1 acc: 0.777777777778
# M2 acc: 0.733333333333
# M1 clf len: 20.0
# M2 clf len: 20.0
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 90
# M1 duration: 0.008438920974731446
# M2 duration: 0.028519511222839355
# M1 acc: 0.833333333333
# M2 acc: 0.744444444444
# M1 clf len: 23.0
# M2 clf len: 23.0
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 200
# M1 duration: 0.017840981483459473
# M2 duration: 0.04253418445587158
# M1 acc: 0.888888888889
# M2 acc: 0.8
# M1 clf len: 31.0
# M2 clf len: 31.0
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 300
# M1 duration: 0.01693007946014404
# M2 duration: 0.09177980422973633
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 400
# M1 duration: 0.02826836109161377
# M2 duration: 0.11836144924163819
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 500
# M1 duration: 0.01687614917755127
# M2 duration: 0.12867658138275145
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 600
# M1 duration: 0.01693007946014404
# M2 duration: 0.11710526943206787
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 700
# M1 duration: 0.018489933013916014
# M2 duration: 0.12026197910308838
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 800
# M1 duration: 0.019629192352294923
# M2 duration: 0.1323998212814331
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 900
# M1 duration: 0.01849362850189209
# M2 duration: 0.13721399307250975
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 2000
# M1 duration: 0.02154524326324463
# M2 duration: 0.13723666667938234
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 3000
# M1 duration: 0.023181700706481935
# M2 duration: 0.17415282726287842
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 4000
# M1 duration: 0.023836612701416016
# M2 duration: 0.23058929443359374
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 5000
# M1 duration: 0.033205938339233396
# M2 duration: 0.18530421257019042
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 6000
# M1 duration: 0.02161378860473633
# M2 duration: 0.19893882274627686
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 7000
# M1 duration: 0.028477740287780762
# M2 duration: 0.13183963298797607
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 8000
# M1 duration: 0.020056509971618654
# M2 duration: 0.12334928512573243
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 9000
# M1 duration: 0.03471016883850098
# M2 duration: 0.16039066314697265
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 20000
# M1 duration: 0.031644606590271
# M2 duration: 0.14187004566192626
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 30000
# M1 duration: 0.021577072143554688
# M2 duration: 0.21675331592559816
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 40000
# M1 duration: 0.023113417625427245
# M2 duration: 0.1757129192352295
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 50000
# M1 duration: 0.04167983531951904
# M2 duration: 0.1340780258178711
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 60000
# M1 duration: 0.021619963645935058
# M2 duration: 0.12716174125671387
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 70000
# M1 duration: 0.02479245662689209
# M2 duration: 0.1355412244796753
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 80000
# M1 duration: 0.020059704780578613
# M2 duration: 0.12502102851867675
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6
#
#
#
# Running apriori with setting: confidence=0.5, support=0.0, minlen=2, maxlen=3, MAX_RULE_LEN=19
# Rule count: 2266, Iteration: 1
# Target rule count satisfied: 1000
# target rule count: 90000
# M1 duration: 0.020058345794677735
# M2 duration: 0.11829533576965331
# M1 acc: 0.888888888889
# M2 acc: 0.844444444444
# M1 clf len: 33.0
# M2 clf len: 36.6

# %%
benchmark_data_pd = pd.DataFrame(benchmark_data)

benchmark_data_pd.plot(x=["rule_count"], y=["M1_duration", "M2_duration"])

# %%
arc_rule_sensitivity = pd.read_csv("../data/arc-rule-sensitivity.csv")

#times_arc = arc_rule_sensitivity[["input rules", "time_rcba", "time_arc", "time_acba"]]
times_arc = arc_rule_sensitivity

times_arc = times_arc.astype({"input rules": int})

times_arc = times_arc.set_index("input rules")

times_arc.head()
# Out:
#                                                        dataset  \
# input rules
# 10           C:/code/python/machine_learning/assoc_rules/te...
# 11           C:/code/python/machine_learning/assoc_rules/te...
# 12           C:/code/python/machine_learning/assoc_rules/te...
# 13           C:/code/python/machine_learning/assoc_rules/te...
# 14           C:/code/python/machine_learning/assoc_rules/te...
#
#              output_rules_arc  output_rules_rcba  output_rules_acba  time_arc  \
# input rules
# 10                          2                  2                  2     0.225
# 11                          2                  2                  2     0.203
# 12                          2                  2                  2     0.286
# 13                          2                  2                  2     0.230
# 14                          2                  2                  2     0.196
#
#              time_rcba  time_acba  acc_arc  acc_rcba  acc_acba
# input rules
# 10               0.170      0.181      0.5       0.5       0.5
# 11               0.115      0.164      0.5       0.5       0.5
# 12               0.164      0.230      0.5       0.5       0.5
# 13               0.131      0.155      0.5       0.5       0.5
# 14               0.113      0.150      0.5       0.5       0.5

# %%
benchmark_data_pd.head()
# Out:
#    M1_accuracy  M1_duration  M1_output_rules  M2_accuracy  M2_duration  \
# 0     0.611111     0.004688             10.0     0.522222     0.018093
# 1     0.611111     0.008416             10.0     0.522222     0.018092
# 2     0.611111     0.005630             10.0     0.522222     0.014747
# 3     0.666667     0.005291             11.0     0.577778     0.018463
# 4     0.666667     0.005344             11.0     0.577778     0.016719
#
#    M2_output_rules  rule_count
# 0             10.0          10
# 1             10.0          11
# 2             10.0          12
# 3             11.0          13
# 4             11.0          14

# %%
benchmark_data_pd.columns = ["acc_pyARC_m1", "time_pyARC_m1", "output_rules_pyARC_m1", "acc_pyARC_m2", "time_pyARC_m2", "output_rules_pyARC_m2", "input rules"]

benchmark_data_pd = benchmark_data_pd.set_index("input rules")

# %%
times_df = benchmark_data_pd.join(times_arc)
times_df
# Out:
#              acc_pyARC_m1  time_pyARC_m1  output_rules_pyARC_m1  acc_pyARC_m2  \
# input rules
# 10               0.611111       0.004688                   10.0      0.522222
# 11               0.611111       0.008416                   10.0      0.522222
# 12               0.611111       0.005630                   10.0      0.522222
# 13               0.666667       0.005291                   11.0      0.577778
# 14               0.666667       0.005344                   11.0      0.577778
# 15               0.666667       0.007813                   12.0      0.577778
# 16               0.722222       0.006903                   13.0      0.633333
# 17               0.722222       0.010309                   14.0      0.633333
# 18               0.722222       0.006582                   14.0      0.633333
# 19               0.722222       0.008464                   14.0      0.633333
# 20               0.722222       0.006901                   14.0      0.633333
# 30               0.722222       0.011566                   15.0      0.677778
# 40               0.722222       0.008465                   17.0      0.677778
# 50               0.777778       0.011591                   18.0      0.733333
# 60               0.833333       0.011590                   20.9      0.733333
# 70               0.833333       0.013151                   23.8      0.733333
# 80               0.833333       0.013156                   23.8      0.733333
# 90               0.833333       0.014455                   24.8      0.744444
# 200              0.888889       0.030007                   36.4      0.800000
# 300              0.888889       0.031744                   46.3      0.844444
# 400              0.888889       0.025633                   48.3      0.844444
# 500              0.888889       0.033012                   49.3      0.844444
# 600              0.888889       0.034683                   49.3      0.844444
# 700              0.888889       0.035369                   49.3      0.844444
# 800              0.888889       0.027809                   49.3      0.844444
# 900              0.888889       0.031564                   49.3      0.844444
# 2000             0.888889       0.032854                   49.3      0.844444
# 3000             0.888889       0.045330                   49.3      0.844444
# 4000             0.888889       0.048575                   49.3      0.844444
# 5000             0.888889       0.041642                   49.3      0.844444
# 6000             0.888889       0.032743                   49.3      0.844444
# 7000             0.888889       0.042372                   49.3      0.844444
# 8000             0.888889       0.043431                   49.3      0.844444
# 9000             0.888889       0.063707                   49.3      0.844444
# 20000            0.888889       0.068618                   49.3      0.844444
# 30000            0.888889       0.063252                   49.3      0.844444
# 40000            0.888889       0.048534                   49.3      0.844444
# 50000            0.888889       0.054197                   49.3      0.844444
# 60000            0.888889       0.064751                   49.3      0.844444
# 70000            0.888889       0.058520                   49.3      0.844444
# 80000            0.888889       0.076414                   49.3      0.844444
# 90000            0.888889       0.061667                   49.3      0.844444
#
#              time_pyARC_m2  output_rules_pyARC_m2  \
# input rules
# 10                0.018093                   10.0
# 11                0.018092                   10.0
# 12                0.014747                   10.0
# 13                0.018463                   11.0
# 14                0.016719                   11.0
# 15                0.020057                   12.0
# 16                0.015365                   13.0
# 17                0.021587                   14.0
# 18                0.020344                   14.0
# 19                0.021570                   14.0
# 20                0.019370                   14.0
# 30                0.020561                   15.0
# 40                0.016933                   17.0
# 50                0.020055                   18.0
# 60                0.023134                   19.0
# 70                0.026511                   20.0
# 80                0.030866                   20.0
# 90                0.025605                   21.0
# 200               0.032828                   25.0
# 300               0.035233                   30.0
# 400               0.032520                   30.0
# 500               0.035565                   30.0
# 600               0.041566                   30.0
# 700               0.032326                   30.0
# 800               0.038472                   30.0
# 900               0.036498                   30.0
# 2000              0.035747                   30.0
# 3000              0.041345                   30.0
# 4000              0.053182                   30.0
# 5000              0.055327                   30.0
# 6000              0.045309                   30.0
# 7000              0.053230                   30.0
# 8000              0.053625                   30.0
# 9000              0.043363                   30.0
# 20000             0.062536                   30.0
# 30000             0.085436                   30.0
# 40000             0.046314                   30.0
# 50000             0.060131                   30.0
# 60000             0.062229                   30.0
# 70000             0.055653                   30.0
# 80000             0.053838                   30.0
# 90000             0.061662                   30.0
#
#                                                        dataset  \
# input rules
# 10           C:/code/python/machine_learning/assoc_rules/te...
# 11           C:/code/python/machine_learning/assoc_rules/te...
# 12           C:/code/python/machine_learning/assoc_rules/te...
# 13           C:/code/python/machine_learning/assoc_rules/te...
# 14           C:/code/python/machine_learning/assoc_rules/te...
# 15           C:/code/python/machine_learning/assoc_rules/te...
# 16           C:/code/python/machine_learning/assoc_rules/te...
# 17           C:/code/python/machine_learning/assoc_rules/te...
# 18           C:/code/python/machine_learning/assoc_rules/te...
# 19           C:/code/python/machine_learning/assoc_rules/te...
# 20           C:/code/python/machine_learning/assoc_rules/te...
# 30           C:/code/python/machine_learning/assoc_rules/te...
# 40           C:/code/python/machine_learning/assoc_rules/te...
# 50           C:/code/python/machine_learning/assoc_rules/te...
# 60           C:/code/python/machine_learning/assoc_rules/te...
# 70           C:/code/python/machine_learning/assoc_rules/te...
# 80           C:/code/python/machine_learning/assoc_rules/te...
# 90           C:/code/python/machine_learning/assoc_rules/te...
# 200          C:/code/python/machine_learning/assoc_rules/te...
# 300          C:/code/python/machine_learning/assoc_rules/te...
# 400          C:/code/python/machine_learning/assoc_rules/te...
# 500          C:/code/python/machine_learning/assoc_rules/te...
# 600          C:/code/python/machine_learning/assoc_rules/te...
# 700          C:/code/python/machine_learning/assoc_rules/te...
# 800          C:/code/python/machine_learning/assoc_rules/te...
# 900          C:/code/python/machine_learning/assoc_rules/te...
# 2000         C:/code/python/machine_learning/assoc_rules/te...
# 3000         C:/code/python/machine_learning/assoc_rules/te...
# 4000         C:/code/python/machine_learning/assoc_rules/te...
# 5000         C:/code/python/machine_learning/assoc_rules/te...
# 6000         C:/code/python/machine_learning/assoc_rules/te...
# 7000         C:/code/python/machine_learning/assoc_rules/te...
# 8000         C:/code/python/machine_learning/assoc_rules/te...
# 9000         C:/code/python/machine_learning/assoc_rules/te...
# 20000        C:/code/python/machine_learning/assoc_rules/te...
# 30000        C:/code/python/machine_learning/assoc_rules/te...
# 40000        C:/code/python/machine_learning/assoc_rules/te...
# 50000        C:/code/python/machine_learning/assoc_rules/te...
# 60000        C:/code/python/machine_learning/assoc_rules/te...
# 70000        C:/code/python/machine_learning/assoc_rules/te...
# 80000        C:/code/python/machine_learning/assoc_rules/te...
# 90000        C:/code/python/machine_learning/assoc_rules/te...
#
#              output_rules_arc  output_rules_rcba  output_rules_acba  time_arc  \
# input rules
# 10                          2                  2                  2     0.225
# 11                          2                  2                  2     0.203
# 12                          2                  2                  2     0.286
# 13                          2                  2                  2     0.230
# 14                          2                  2                  2     0.196
# 15                          2                  2                  2     0.192
# 16                          2                  2                  2     0.209
# 17                          2                  2                  2     0.245
# 18                          2                  2                  2     0.225
# 19                          2                  2                  2     0.186
# 20                          2                  2                  2     0.213
# 30                          2                  6                  4     0.211
# 40                          9                  9                  6     0.245
# 50                          9                  9                  8     0.359
# 60                          9                  9                  7     0.274
# 70                         11                 12                  9     0.167
# 80                         11                 12                  9     0.239
# 90                          9                  9                 10     0.233
# 200                        10                 11                 10     0.227
# 300                        15                 16                 15     0.178
# 400                        19                 20                 19     0.269
# 500                        22                 24                 23     0.247
# 600                        27                 23                 25     0.298
# 700                        23                 23                 28     0.266
# 800                        26                 26                 31     0.706
# 900                        30                 29                 31     0.531
# 2000                       28                 28                 29     0.361
# 3000                       32                 32                 33     0.678
# 4000                       31                 31                 32     0.743
# 5000                       34                 34                 35     0.928
# 6000                       33                 32                 35     0.996
# 7000                       32                 32                 35     2.456
# 8000                       35                 35                 35     1.928
# 9000                       39                 39                 39     4.686
# 20000                      39                 39                 37     7.664
# 30000                      39                 39                 37    17.223
# 40000                      39                 39                 37    19.828
# 50000                      38                 38                 37    27.380
# 60000                      39                 39                 38    25.588
# 70000                      37                 37                 36    25.534
# 80000                      37                 37                 36    37.928
# 90000                      37                 37                 36    56.492
#
#              time_rcba  time_acba   acc_arc  acc_rcba  acc_acba
# input rules
# 10               0.170      0.181  0.500000  0.500000  0.500000
# 11               0.115      0.164  0.500000  0.500000  0.500000
# 12               0.164      0.230  0.500000  0.500000  0.500000
# 13               0.131      0.155  0.500000  0.500000  0.500000
# 14               0.113      0.150  0.500000  0.500000  0.500000
# 15               0.110      0.177  0.500000  0.500000  0.500000
# 16               0.117      0.155  0.500000  0.500000  0.500000
# 17               0.132      0.173  0.500000  0.500000  0.500000
# 18               0.130      0.159  0.500000  0.500000  0.500000
# 19               0.113      0.168  0.500000  0.500000  0.500000
# 20               0.151      0.177  0.500000  0.500000  0.500000
# 30               0.129      0.164  0.611111  0.611111  0.611111
# 40               0.162      0.278  0.722222  0.666667  0.666667
# 50               0.264      0.218  0.722222  0.722222  0.666667
# 60               0.122      0.158  0.722222  0.722222  0.722222
# 70               0.294      0.274  0.722222  0.722222  0.722222
# 80               0.209      0.214  0.722222  0.722222  0.722222
# 90               0.137      0.180  0.722222  0.722222  0.722222
# 200              0.148      0.146  0.777778  0.777778  0.777778
# 300              0.172      0.185  0.722222  0.722222  0.777778
# 400              0.175      0.178  0.722222  0.722222  0.777778
# 500              0.172      0.143  0.777778  0.777778  0.833333
# 600              0.184      0.152  0.777778  0.833333  0.833333
# 700              0.193      0.224  0.888889  0.888889  0.777778
# 800              0.401      0.246  0.888889  0.833333  0.833333
# 900              0.290      0.230  0.888889  0.833333  0.888889
# 2000             0.332      0.209  0.888889  0.888889  0.888889
# 3000             0.586      0.228  0.888889  0.833333  0.888889
# 4000             0.622      0.388  0.888889  0.722222  0.888889
# 5000             0.719      0.422  0.833333  0.777778  0.833333
# 6000             1.160      0.790  0.722222  0.666667  0.777778
# 7000             1.776      0.598  0.722222  0.666667  0.777778
# 8000             2.314      0.858  0.777778  0.722222  0.777778
# 9000             1.623      0.606  0.777778  0.722222  0.777778
# 20000            3.933      1.264  0.833333  0.777778  0.833333
# 30000            6.185      1.806  0.833333  0.777778  0.833333
# 40000           13.078      3.166  0.833333  0.777778  0.833333
# 50000           11.037      3.182  0.833333  0.777778  0.777778
# 60000            9.324      2.834  0.833333  0.777778  0.833333
# 70000           12.616      3.691  0.777778  0.777778  0.777778
# 80000           21.925      7.307  0.777778  0.777778  0.777778
# 90000           25.685      6.422  0.777778  0.777778  0.777778

# %%
times_df["input rules"] = times_df.index

labels = ["pyARC - m1", "pyARC - m2", "arc", "rCBA", "arulesCBA"]

# %%
import matplotlib.pyplot as plt

ax = times_df.plot(x=["input rules"], y=["time_pyARC_m1", "time_pyARC_m2", "time_arc", "time_rcba", "time_acba"])
ax.legend(labels)

plt.savefig('../data/rule_sensitivity_plot.png')

# %%
import matplotlib.pyplot as plt

ax = times_df.plot(subplots=True, sharey=True, sharex=True, figsize=(5, 10), x=["input rules"], y=["acc_pyARC_m1", "acc_pyARC_m2", "acc_arc", "acc_rcba", "acc_acba"])



plt.savefig('../data/rule_sensitivity_plot_accuracy.png')

# %%
import matplotlib.pyplot as plt


times_df.plot(subplots=True, sharey=True, sharex=True, figsize=(5, 10), x=["input rules"], y=["output_rules_pyARC_m1", "output_rules_pyARC_m2", "output_rules_arc", "output_rules_rcba", "output_rules_acba"])




plt.savefig('../data/rule_sensitivity_plot_output_rules.png')

# %%
#benchmark_data_pd.to_csv("../data/benchmark_rules_sensitivity.csv")
#benchmark_data_pd = pd.read_csv("../data/benchmark_rules_sensitivity.csv")

#benchmark_data_pd.plot(x=["rule_count"], y=["M1_duration", "M2_duration"])

# %%
window = 10

benchmark_data_pd["M1_duration_rolling"] = benchmark_data_pd["M1_duration"].rolling(window=window, center=False).mean()

benchmark_data_pd["M2_duration_rolling"] = benchmark_data_pd["M2_duration"].rolling(window=window, center=False).mean()

benchmark_data_pd.plot(x=["rule_count"], y=["M1_duration_rolling", "M2_duration_rolling"])
