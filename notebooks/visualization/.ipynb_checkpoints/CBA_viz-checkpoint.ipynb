# %%
# %run ../../main.py
# %matplotlib inline

# %%
# vyřešení, proč M1 a M2 vrací různé klasifikátory

# ruční průchod M1


# pro každé pravidlo
"""
i = 0

dataset = set(transactionDB)

print("r", i, ":", sep="")
print(rules[i])
print("\n")

r = rules[i]

temp = set()
instances_satisfying = []
for d in dataset:
    if r.antecedent <= d:
        print("satisfies antecedent:", d)
        temp.add(d)
        if r.consequent == d.class_val:
            print("and has same class")
        print("\n")
        
dataset -= temp
        
i += 1
        
        
print("r", i, ":", sep="")
print(rules[i])
print("\n")

r = rules[i]

temp = set()
instances_satisfying = []
for d in dataset:
    if r.antecedent <= d:
        print("satisfies antecedent:", d)
        temp.add(d)
        if r.consequent == d.class_val:
            print("and has same class")
        print("\n")
        
dataset -= temp
        
i += 1



print("r", i, ":", sep="")
print(rules[i])
print("\n")

r = rules[i]

temp = set()
instances_satisfying = []
for d in dataset:
    if r.antecedent <= d:
        print("satisfies antecedent:", d)
        temp.add(d)
        if r.consequent == d.class_val:
            print("and has same class")
        print("\n")
        
dataset -= temp
        
i += 1


print("r", i, ":", sep="")
print(rules[i])
print("\n")

r = rules[i]

temp = set()
instances_satisfying = []
for d in dataset:
    if r.antecedent <= d:
        print("satisfies antecedent:", d)
        temp.add(d)
        if r.consequent == d.class_val:
            print("and has same class")
        print("\n")
        
dataset -= temp
        
i += 1


print("r", i, ":", sep="")
print(rules[i])
print("\n")

r = rules[i]

temp = set()
instances_satisfying = []
for d in dataset:
    if r.antecedent <= d:
        print("satisfies antecedent:", d)
        temp.add(d)
        if r.consequent == d.class_val:
            print("and has same class")
        print("\n")
        
dataset -= temp
        
i += 1

print("r", i, ":", sep="")
print(rules[i])
print("\n")

r = rules[i]

temp = set()
instances_satisfying = []
for d in dataset:
    if r.antecedent <= d:
        print("satisfies antecedent:", d)
        temp.add(d)
        if r.consequent == d.class_val:
            print("and has same class")
        print("\n")
        
dataset -= temp
        
i += 1


print("r", i, ":", sep="")
print(rules[i])
print("\n")

r = rules[i]

temp = set()
instances_satisfying = []
for d in dataset:
    if r.antecedent <= d:
        print("satisfies antecedent:", d)
        temp.add(d)
        if r.consequent == d.class_val:
            print("and has same class")
        print("\n")
        
dataset -= temp
        
i += 1

print("r", i, ":", sep="")
print(rules[i])
print("\n")

r = rules[i]

temp = set()
instances_satisfying = []
for d in dataset:
    if r.antecedent <= d:
        print("satisfies antecedent:", d)
        temp.add(d)
        if r.consequent == d.class_val:
            print("and has same class")
        print("\n")
        
dataset -= temp
        
i += 1

print("r", i, ":", sep="")
print(rules[i])
print("\n")

r = rules[i]

temp = set()
instances_satisfying = []
for d in dataset:
    if r.antecedent <= d:
        print("satisfies antecedent:", d)
        temp.add(d)
        if r.consequent == d.class_val:
            print("and has same class")
        print("\n")
        
dataset -= temp
        
i += 1

print("r", i, ":", sep="")
print(rules[i])
print("\n")

r = rules[i]

temp = set()
instances_satisfying = []
for d in dataset:
    if r.antecedent <= d:
        print("satisfies antecedent:", d)
        temp.add(d)
        if r.consequent == d.class_val:
            print("and has same class")
        print("\n")
        
dataset -= temp
        
i += 1
"""
None

# %%
# implementace CBA v numpy
"""
import numpy as np


np_t = np.array(transactionDB.string_representation)
np_rules = []

mask = np.logical_and(np_t[:, 1] == 'a-list-celebrities:=:<0;2)', np_t[:, 0] == 'estimated-budget:=:<0;50)')

np_t[mask]



def transform_rules_to_np_array(rules, tDB):
    transformed_rls = []
    
    for r in rules:
        rule_dict = {}
        for attribute in tDB.header[:-1]:
            rule_dict[attribute] = getattr(r.antecedent, attribute, np.nan)

        classname = tDB.header[-1]
        rule_dict[classname] = r.consequent.value
        
        transformed_rls.append(rule_dict)
        
    dataframe = pd.DataFrame(transformed_rls)
    
    #reorder columns
    dataframe = dataframe[tDB.header]
    
    return dataframe.values


def transform_rules_to_np_array2(rules, tDB):
    transformed_rls = []
    
    for r in rules:
        rule_list = []
        for attribute in tDB.header[:-1]:
            recovered_att = getattr(r.antecedent, attribute, np.nan)
            if recovered_att is np.nan:
                rule_list.append(np.nan)
            else:
                string = "{}:=:{}".format(attribute, getattr(r.antecedent, attribute, np.nan))
                rule_list.append(string)

        classname = tDB.header[-1]
        rule_list.append("{}:=:{}".format(classname, r.consequent.value))
        
        transformed_rls.append(rule_list)
        
    dataframe = pd.DataFrame(transformed_rls)
    
    #reorder columns
    dataframe.cols = tDB.header
    
    return dataframe.values
        
            
        
    
df = transform_rules_to_np_array2(rules, transactionDB)

r = df[0]

r

mask_nan = [False if str(n) == "nan" else True for n in r]
r_notnan = r[mask_nan]


#np.logical_and(np_t, *[ np_t == item for item in r_notnan ])


r_notnan


"""
None

# %%
from cba import CBA
from cba import generateCARs, M1Algorithm, M2Algorithm
from cba.algorithms import createCARs



import matplotlib.pyplot as plt
import matplotlib.patches as patches

from itertools import combinations

import itertools
import pandas as pd
import numpy
import re

movies = pd.read_csv("../data/movies.csv", sep=";")
movies_discr = movies.copy(True)



budget_bins = range(0, 350, 50)
budget_bins_names = [ "<{0};{1})".format(i, i + 50) for i in budget_bins[:-1] ]

celebrities_bins = range(0, 10, 2)
celebrities_bins_names = [ "<{0};{1})".format(i, i + 2) for i in celebrities_bins[:-1] ]

movies_discr['estimated-budget'] = pd.cut(movies['estimated-budget'], budget_bins, labels=budget_bins_names)
movies_discr['a-list-celebrities'] = pd.cut(movies['a-list-celebrities'], celebrities_bins, labels=celebrities_bins_names)

#movies_discr.to_csv("../data/movies_discr.csv", sep=";")
movies_discr = movies_discr.iloc[:10,:]

transactionDB = TransactionDB.from_pandasdf(movies_discr)

rules = generateCARs(transactionDB, support=5, confidence=50)

movies_vals = movies.get_values()


x = range(0, 350, 50)
y = range(1, 9)


x_points = list(map(lambda n: n[0], movies_vals))
y_points = list(map(lambda n: n[1], movies_vals))
data_class = list(movies['class'])
appearance = {
    'box-office-bomb': ('brown', "o"),
    'main-stream-hit': ('blue', "o"),
    'critical-success': ('green', "o")
}
rule_appearance = {
    'box-office-bomb': 'tan',
    'main-stream-hit': 'aqua',
    'critical-success': 'lightgreen'
}


plt.style.use('seaborn-white')
rules
# Out:
# [CAR {a-list-celebrities=<0;2)} => {class=box-office-bomb} s: 0.70 c: 1.00 l: 2,
#  CAR {a-list-celebrities=<2;4)} => {class=box-office-bomb} s: 0.30 c: 1.00 l: 2,
#  CAR {estimated-budget=<50;100)} => {class=box-office-bomb} s: 0.30 c: 1.00 l: 2,
#  CAR {estimated-budget=<150;200)} => {class=box-office-bomb} s: 0.30 c: 1.00 l: 2,
#  CAR {estimated-budget=<200;250)} => {class=box-office-bomb} s: 0.20 c: 1.00 l: 2,
#  CAR {a-list-celebrities=<0;2),estimated-budget=<50;100)} => {class=box-office-bomb} s: 0.20 c: 1.00 l: 3,
#  CAR {a-list-celebrities=<0;2),estimated-budget=<150;200)} => {class=box-office-bomb} s: 0.20 c: 1.00 l: 3,
#  CAR {estimated-budget=<100;150)} => {class=box-office-bomb} s: 0.10 c: 1.00 l: 2,
#  CAR {estimated-budget=<0;50)} => {class=box-office-bomb} s: 0.10 c: 1.00 l: 2,
#  CAR {a-list-celebrities=<2;4),estimated-budget=<50;100)} => {class=box-office-bomb} s: 0.10 c: 1.00 l: 3,
# ...

# %%
movies_discr
# Out:
# estimated-budget             <50;100)
# a-list-celebrities              <2;4)
# class                 main-stream-hit
# Name: 18, dtype: object

# %%
import numpy as np

arr = np.arange(9)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-99cddf048baf> in <module>()
#       3 arr = np.arange(9)
#       4
# ----> 5 arr.itemset(1)
#       6
#
# IndexError: index 2717814410912 is out of bounds for axis 0 with size 9
