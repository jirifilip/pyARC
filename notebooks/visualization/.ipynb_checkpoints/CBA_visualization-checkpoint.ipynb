# %%
# %run ../../main.py
# %matplotlib inline

# %%
from cba import CBA
from cba import generateCARs, M1Algorithm, M2Algorithm
from cba.algorithms import createCARs



import matplotlib.pyplot as plt
import matplotlib.patches as patches

from itertools import combinations

import itertools
import pandas as pd
import numpy
import re

movies = pd.read_csv("../data/movies.csv", sep=";")
movies_discr = movies.copy(True)



budget_bins = range(0, 350, 50)
budget_bins_names = [ "<{0};{1})".format(i, i + 50) for i in budget_bins[:-1] ]

celebrities_bins = range(0, 10, 2)
celebrities_bins_names = [ "<{0};{1})".format(i, i + 2) for i in celebrities_bins[:-1] ]

movies_discr['estimated-budget'] = pd.cut(movies['estimated-budget'], budget_bins, labels=budget_bins_names)
movies_discr['a-list-celebrities'] = pd.cut(movies['a-list-celebrities'], celebrities_bins, labels=celebrities_bins_names)

movies_discr.to_csv("../data/movies_discr.csv", sep=";")

transactionDB = TransactionDB.from_pandasdf(movies_discr)

rules = generateCARs(transactionDB, support=5, confidence=50)

movies_vals = movies.get_values()


x = range(0, 350, 50)
y = range(1, 9)


x_points = list(map(lambda n: n[0], movies_vals))
y_points = list(map(lambda n: n[1], movies_vals))
data_class = list(movies['class'])
appearance = {
    'box-office-bomb': ('brown', "o"),
    'main-stream-hit': ('blue', "o"),
    'critical-success': ('green', "o")
}
rule_appearance = {
    'box-office-bomb': 'tan',
    'main-stream-hit': 'aqua',
    'critical-success': 'lightgreen'
}


plt.style.use('seaborn-white')
rules
# Out:
# [CAR {a-list-celebrities=<0;2)} => {class=box-office-bomb} s: 0.31 c: 1.00 l: 2,
#  CAR {estimated-budget=<0;50),a-list-celebrities=<0;2)} => {class=box-office-bomb} s: 0.11 c: 1.00 l: 3,
#  CAR {a-list-celebrities=<0;2),estimated-budget=<50;100)} => {class=box-office-bomb} s: 0.09 c: 1.00 l: 3,
#  CAR {estimated-budget=<250;300)} => {class=main-stream-hit} s: 0.06 c: 1.00 l: 2,
#  CAR {estimated-budget=<0;50),a-list-celebrities=<4;6)} => {class=critical-success} s: 0.06 c: 1.00 l: 3,
#  CAR {estimated-budget=<150;200),a-list-celebrities=<0;2)} => {class=box-office-bomb} s: 0.06 c: 1.00 l: 3,
#  CAR {estimated-budget=<200;250)} => {class=box-office-bomb} s: 0.06 c: 0.67 l: 2,
#  CAR {a-list-celebrities=<4;6),estimated-budget=<50;100)} => {class=critical-success} s: 0.06 c: 0.67 l: 3,
#  CAR {estimated-budget=<0;50)} => {class=box-office-bomb} s: 0.14 c: 0.62 l: 2,
#  CAR {a-list-celebrities=<4;6)} => {class=main-stream-hit} s: 0.11 c: 0.50 l: 2,
#  CAR {a-list-celebrities=<4;6)} => {class=critical-success} s: 0.11 c: 0.50 l: 2,
#  CAR {estimated-budget=<100;150)} => {class=box-office-bomb} s: 0.06 c: 0.50 l: 2,
#  CAR {estimated-budget=<100;150)} => {class=main-stream-hit} s: 0.06 c: 0.50 l: 2,
#  CAR {a-list-celebrities=<2;4),estimated-budget=<50;100)} => {class=box-office-bomb} s: 0.06 c: 0.50 l: 3,
#  CAR {estimated-budget=<150;200),a-list-celebrities=<2;4)} => {class=critical-success} s: 0.06 c: 0.50 l: 3,
#  CAR {estimated-budget=<0;50),a-list-celebrities=<2;4)} => {class=box-office-bomb} s: 0.03 c: 0.50 l: 3,
#  CAR {estimated-budget=<0;50),a-list-celebrities=<2;4)} => {class=critical-success} s: 0.03 c: 0.50 l: 3,
#  CAR {estimated-budget=<100;150),a-list-celebrities=<2;4)} => {class=box-office-bomb} s: 0.03 c: 0.50 l: 3,
#  CAR {estimated-budget=<100;150),a-list-celebrities=<2;4)} => {class=main-stream-hit} s: 0.03 c: 0.50 l: 3,
#  CAR {estimated-budget=<200;250),a-list-celebrities=<2;4)} => {class=box-office-bomb} s: 0.03 c: 0.50 l: 3,
#  CAR {estimated-budget=<200;250),a-list-celebrities=<2;4)} => {class=main-stream-hit} s: 0.03 c: 0.50 l: 3]

# %%
from cba.algorithms import Classifier
clf = Classifier()
clf.rules = rules

# %%
# implementace CBA v numpy
import numpy as np


np_t = np.array(transactionDB.string_representation)
np_rules = []

mask = np.logical_and(np_t[:, 1] == 'a-list-celebrities:=:<0;2)', np_t[:, 0] == 'estimated-budget:=:<0;50)')

np_t[mask]



def transform_rules_to_np_array(rules, tDB):
    transformed_rls = []
    
    for r in rules:
        rule_dict = {}
        for attribute in tDB.header[:-1]:
            rule_dict[attribute] = getattr(r.antecedent, attribute, np.nan)

        classname = tDB.header[-1]
        rule_dict[classname] = r.consequent.value
        
        transformed_rls.append(rule_dict)
        
    dataframe = pd.DataFrame(transformed_rls)
    
    #reorder columns
    dataframe = dataframe[tDB.header]
    
    return dataframe.values


def transform_rules_to_np_array2(rules, tDB):
    transformed_rls = []
    
    for r in rules:
        rule_list = []
        for attribute in tDB.header[:-1]:
            recovered_att = getattr(r.antecedent, attribute, np.nan)
            if recovered_att is np.nan:
                rule_list.append(np.nan)
            else:
                string = "{}:=:{}".format(attribute, getattr(r.antecedent, attribute, np.nan))
                rule_list.append(string)

        classname = tDB.header[-1]
        rule_list.append("{}:=:{}".format(classname, r.consequent.value))
        
        transformed_rls.append(rule_list)
        
    dataframe = pd.DataFrame(transformed_rls)
    
    #reorder columns
    dataframe.cols = tDB.header
    
    return dataframe.values
        
            
        
    
df = transform_rules_to_np_array2(rules, transactionDB)

r = df[0]

r

mask_nan = [False if str(n) == "nan" else True for n in r]
r_notnan = r[mask_nan]


#np.logical_and(np_t, *[ np_t == item for item in r_notnan ])


r_notnan
# Out:
# array(['a-list-celebrities:=:<0;2)', 'class:=:box-office-bomb'], dtype=object)

# %%
# vyřešení, proč M1 a M2 vrací různé klasifikátory

# ruční průchod M1


# pro každé pravidlo
i = 0

dataset = set(transactionDB)

print("r", i, ":", sep="")
print(rules[i])
print("\n")

r = rules[i]

temp = set()
instances_satisfying = []
for d in dataset:
    if r.antecedent <= d:
        print("satisfies antecedent:", d)
        temp.add(d)
        if r.consequent == d.class_val:
            print("and has same class")
        print("\n")
        
dataset -= temp
        
i += 1
        
        
print("r", i, ":", sep="")
print(rules[i])
print("\n")

r = rules[i]

temp = set()
instances_satisfying = []
for d in dataset:
    if r.antecedent <= d:
        print("satisfies antecedent:", d)
        temp.add(d)
        if r.consequent == d.class_val:
            print("and has same class")
        print("\n")
        
dataset -= temp
        
i += 1



print("r", i, ":", sep="")
print(rules[i])
print("\n")

r = rules[i]

temp = set()
instances_satisfying = []
for d in dataset:
    if r.antecedent <= d:
        print("satisfies antecedent:", d)
        temp.add(d)
        if r.consequent == d.class_val:
            print("and has same class")
        print("\n")
        
dataset -= temp
        
i += 1


print("r", i, ":", sep="")
print(rules[i])
print("\n")

r = rules[i]

temp = set()
instances_satisfying = []
for d in dataset:
    if r.antecedent <= d:
        print("satisfies antecedent:", d)
        temp.add(d)
        if r.consequent == d.class_val:
            print("and has same class")
        print("\n")
        
dataset -= temp
        
i += 1


print("r", i, ":", sep="")
print(rules[i])
print("\n")

r = rules[i]

temp = set()
instances_satisfying = []
for d in dataset:
    if r.antecedent <= d:
        print("satisfies antecedent:", d)
        temp.add(d)
        if r.consequent == d.class_val:
            print("and has same class")
        print("\n")
        
dataset -= temp
        
i += 1

print("r", i, ":", sep="")
print(rules[i])
print("\n")

r = rules[i]

temp = set()
instances_satisfying = []
for d in dataset:
    if r.antecedent <= d:
        print("satisfies antecedent:", d)
        temp.add(d)
        if r.consequent == d.class_val:
            print("and has same class")
        print("\n")
        
dataset -= temp
        
i += 1


print("r", i, ":", sep="")
print(rules[i])
print("\n")

r = rules[i]

temp = set()
instances_satisfying = []
for d in dataset:
    if r.antecedent <= d:
        print("satisfies antecedent:", d)
        temp.add(d)
        if r.consequent == d.class_val:
            print("and has same class")
        print("\n")
        
dataset -= temp
        
i += 1

print("r", i, ":", sep="")
print(rules[i])
print("\n")

r = rules[i]

temp = set()
instances_satisfying = []
for d in dataset:
    if r.antecedent <= d:
        print("satisfies antecedent:", d)
        temp.add(d)
        if r.consequent == d.class_val:
            print("and has same class")
        print("\n")
        
dataset -= temp
        
i += 1

print("r", i, ":", sep="")
print(rules[i])
print("\n")

r = rules[i]

temp = set()
instances_satisfying = []
for d in dataset:
    if r.antecedent <= d:
        print("satisfies antecedent:", d)
        temp.add(d)
        if r.consequent == d.class_val:
            print("and has same class")
        print("\n")
        
dataset -= temp
        
i += 1

print("r", i, ":", sep="")
print(rules[i])
print("\n")

r = rules[i]

temp = set()
instances_satisfying = []
for d in dataset:
    if r.antecedent <= d:
        print("satisfies antecedent:", d)
        temp.add(d)
        if r.consequent == d.class_val:
            print("and has same class")
        print("\n")
        
dataset -= temp
        
i += 1
# Out:
# r0:
# CAR {a-list-celebrities=<0;2)} => {class=box-office-bomb} s: 0.31 c: 1.00 l: 2
#
#
# satisfies antecedent: {estimated-budget:=:<200;250), a-list-celebrities:=:<0;2), class:=:box-office-bomb}
# and has same class
#
#
# satisfies antecedent: {estimated-budget:=:<50;100), a-list-celebrities:=:<0;2), class:=:box-office-bomb}
# and has same class
#
#
# satisfies antecedent: {estimated-budget:=:<100;150), a-list-celebrities:=:<0;2), class:=:box-office-bomb}
# and has same class
#
#
# satisfies antecedent: {estimated-budget:=:<0;50), a-list-celebrities:=:<0;2), class:=:box-office-bomb}
# and has same class
#
#
# satisfies antecedent: {estimated-budget:=:<150;200), a-list-celebrities:=:<0;2), class:=:box-office-bomb}
# and has same class
#
#
# r1:
# CAR {estimated-budget=<0;50),a-list-celebrities=<0;2)} => {class=box-office-bomb} s: 0.11 c: 1.00 l: 3
#
#
# r2:
# CAR {estimated-budget=<50;100),a-list-celebrities=<0;2)} => {class=box-office-bomb} s: 0.09 c: 1.00 l: 3
#
#
# r3:
# CAR {estimated-budget=<250;300)} => {class=main-stream-hit} s: 0.06 c: 1.00 l: 2
#
#
# satisfies antecedent: {estimated-budget:=:<250;300), a-list-celebrities:=:<4;6), class:=:main-stream-hit}
# and has same class
#
#
# satisfies antecedent: {estimated-budget:=:<250;300), a-list-celebrities:=:<2;4), class:=:main-stream-hit}
# and has same class
#
#
# r4:
# CAR {a-list-celebrities=<4;6),estimated-budget=<0;50)} => {class=critical-success} s: 0.06 c: 1.00 l: 3
#
#
# satisfies antecedent: {estimated-budget:=:<0;50), a-list-celebrities:=:<4;6), class:=:critical-success}
# and has same class
#
#
# r5:
# CAR {estimated-budget=<150;200),a-list-celebrities=<0;2)} => {class=box-office-bomb} s: 0.06 c: 1.00 l: 3
#
#
# r6:
# CAR {estimated-budget=<200;250)} => {class=box-office-bomb} s: 0.06 c: 0.67 l: 2
#
#
# satisfies antecedent: {estimated-budget:=:<200;250), a-list-celebrities:=:<2;4), class:=:box-office-bomb}
# and has same class
#
#
# r7:
# CAR {a-list-celebrities=<4;6),estimated-budget=<50;100)} => {class=critical-success} s: 0.06 c: 0.67 l: 3
#
#
# satisfies antecedent: {estimated-budget:=:<50;100), a-list-celebrities:=:<4;6), class:=:main-stream-hit}
#
#
# r8:
# CAR {estimated-budget=<0;50)} => {class=box-office-bomb} s: 0.14 c: 0.62 l: 2
#
#
# satisfies antecedent: {estimated-budget:=:<0;50), a-list-celebrities:=:<2;4), class:=:box-office-bomb}
# and has same class
#
#
# r9:
# CAR {a-list-celebrities=<4;6)} => {class=critical-success} s: 0.11 c: 0.50 l: 2
#
#
# satisfies antecedent: {estimated-budget:=:<100;150), a-list-celebrities:=:<4;6), class:=:main-stream-hit}
#
#
# satisfies antecedent: {estimated-budget:=:<150;200), a-list-celebrities:=:<4;6), class:=:main-stream-hit}

# %%
def plot_rule(rule, plt):
    interval_regex = "<(\d+);(\d+)\)"
    
    lower_y = 0
    area_y = celebrities_bins[-1]
    
    lower_x = 0
    area_x = budget_bins[-1]
    
    
    
    
    if len(rule.antecedent) != 0:
        if rule.antecedent[0][0] == "a-list-celebrities":
            y = rule.antecedent[0]
            y_boundaries = re.search(interval_regex, y[1])
            lower_y = float(y_boundaries.group(1))
            upper_y = float(y_boundaries.group(2))
            area_y = upper_y - lower_y

            axis = plt.gca()
        else:
            x = rule.antecedent[0]
            x_boundaries = re.search(interval_regex, x[1])
            lower_x = float(x_boundaries.group(1))
            upper_x = float(x_boundaries.group(2))
            area_x = upper_x - lower_x
        
    if len(rule.antecedent) > 1:
        if rule.antecedent[1][0] == "a-list-celebrities":
            y = rule.antecedent[1]
            y_boundaries = re.search(interval_regex, y[1])
            lower_y = float(y_boundaries.group(1))
            upper_y = float(y_boundaries.group(2))
            area_y = upper_y - lower_y

            axis = plt.gca()
        else:
            x = rule.antecedent[1]
            x_boundaries = re.search(interval_regex, x[1])
            lower_x = float(x_boundaries.group(1))
            upper_x = float(x_boundaries.group(2))
            area_x = upper_x - lower_x
            
    
    axis = plt.gca()

    class_name = rule.consequent[1]
    
    axis.add_patch(
       patches.Rectangle((lower_x, lower_y), area_x, area_y, zorder=-2, facecolor=rule_appearance[class_name], alpha=rule.confidence)
    )

# %%
plt.figure(figsize=(10, 5))

# data cases
for i in range(len(x_points)):
    plt.scatter(x_points[i], y_points[i], marker=appearance[data_class[i]][1], color=appearance[data_class[i]][0], s=60)


    
plt.xlabel('Estimated Budget (1000$)', fontsize=20)
plt.ylabel('A-List Celebrities', fontsize=20)



plt.savefig("../data/datacases.png")

print("rule count", len(rules))
# Out:
# rule count 21

# %%
movies_discr.head()
# Out:
#   estimated-budget a-list-celebrities            class
# 0        <150;200)              <0;2)  box-office-bomb
# 1         <50;100)              <0;2)  box-office-bomb
# 2         <50;100)              <0;2)  box-office-bomb
# 3         <50;100)              <2;4)  box-office-bomb
# 4        <200;250)              <0;2)  box-office-bomb

# %%
plt.figure(figsize=(10, 5))

# data cases
for i in range(len(x_points)):
    plt.scatter(x_points[i], y_points[i], marker=appearance[data_class[i]][1], color=appearance[data_class[i]][0], s=60)


# rule boundary lines
for i, n in enumerate(x):
    plt.axhline(y=y[i], color = "grey", linestyle="dashed")
    plt.axvline(x=x[i], color = "grey", linestyle="dashed")

    
    
plt.xlabel('Estimated Budget (1000$)', fontsize=20)
plt.ylabel('A-List Celebrities', fontsize=20)



plt.savefig("../data/datacases_discr.png")

print("rule count", len(rules))
# Out:
# rule count 21

# %%
subplot_count = 1
plt.style.use("seaborn-white")

fig, ax = plt.subplots(figsize=(40, 60))

ax.set_xlabel('Estimated Budget (1000$)')
ax.set_ylabel('A-List Celebrities')

for idx, r in enumerate(sorted(rules, reverse=True)):
    plt.subplot(7, 4, idx + 1)
    plot_rule(r, plt)
    
    # data cases
    for i in range(len(x_points)):
        plt.scatter(x_points[i], y_points[i], marker=appearance[data_class[i]][1], color=appearance[data_class[i]][0], s=30)

    # rule boundary lines
    for i, n in enumerate(x):
        plt.axhline(y=y[i], color = "grey", linestyle="dashed")
        plt.axvline(x=x[i], color = "grey", linestyle="dashed")
        
        
    plt.xlabel("r{}".format(idx), fontsize=40)
        
        
plt.savefig("../data/rule_plot.png")

# %%
clfm1 = M1Algorithm(rules, transactionDB).build()
print(len(clfm1.rules))
clfm1 = M1Algorithm(rules, transactionDB).build()
print(len(clfm1.rules))
clfm1 = M1Algorithm(rules, transactionDB).build()
print(len(clfm1.rules))
# Out:
# 0
# 3
# 5
# 6
# 8
# 9
# 12
# 14
# 8
# 0
# 3
# 4
# 6
# 8
# 10
# 11
# 13
# 8
# 0
# 3
# 5
# 6
# 8
# 9
# 12
# 14
# 8

# %%
clf = M1Algorithm(rules, transactionDB).build()

for r in clf.rules:
    plot_rule(r, plt)

# data cases
for i in range(len(x_points)):
    plt.scatter(x_points[i], y_points[i], marker=appearance[data_class[i]][1], color=appearance[data_class[i]][0], s=60)


# rule boundary lines
for i, n in enumerate(x):
    plt.axhline(y=y[i], color = "grey", linestyle="dashed")
    plt.axvline(x=x[i], color = "grey", linestyle="dashed")

    
    
plt.xlabel('Estimated Budget (1000$)')
plt.ylabel('A-List Celebrities')
# Out:
# 0
# 3
# 4
# 6
# 8
# 10
# 11
# 13

# %%
clfm1 = M1Algorithm(rules, transactionDB).build()

fig, ax = plt.subplots(figsize=(60, 20))
for idx, r in enumerate(clfm1.rules):
    plt.subplot(2, 5, idx + 1)
    
    for rule in clfm1.rules[:idx+1]:
        plot_rule(rule, plt)
        
    #plot_rule(r, plt)
    
    for i in range(len(x_points)):
        plt.scatter(x_points[i], y_points[i], marker=appearance[data_class[i]][1], color=appearance[data_class[i]][0], s=60)

    for i, n in enumerate(x):
        plt.axhline(y=y[i], color = "grey", linestyle="dashed")
        plt.axvline(x=x[i], color = "grey", linestyle="dashed")
    
    plt.xlabel("Krok {}".format(idx + 1), fontsize=40)
    
    
    
plt.savefig("../data/m1_rules.png")
# Out:
# 0
# 3
# 5
# 6
# 8
# 9
# 12
# 14

# %%
len(clfm1.rules)
# Out:
# 10

# %%
m2 = M2Algorithm(rules, transactionDB)
clfm2 = m2.build()


fig, ax = plt.subplots(figsize=(40, 16))
for idx, r in enumerate(clfm2.rules):
    plt.subplot(2, 5, idx + 1)
    
    for rule in clfm2.rules[:idx+1]:
        plot_rule(rule, plt)
    
    for i in range(len(x_points)):
        plt.scatter(x_points[i], y_points[i], marker=appearance[data_class[i]][1], color=appearance[data_class[i]][0], s=60)

    for i, n in enumerate(x):
        plt.axhline(y=y[i], color = "grey", linestyle="dashed")
        plt.axvline(x=x[i], color = "grey", linestyle="dashed")
    
    plt.xlabel("Krok {}".format(idx + 1), fontsize=40)
    
    
    
plt.savefig("../data/m2_rules.png")

# %%
len(clfm2.rules)
# Out:
# 8

# %%
clfm2.inspect().to_csv("../data/rulesframe.csv")

# %%
import sklearn.metrics as skmetrics

m1pred = clfm1.predict_all(transactionDB)
m2pred = clfm2.predict_all(transactionDB)

actual = transactionDB.classes


m1acc = skmetrics.accuracy_score(m1pred, actual)
m2acc = skmetrics.accuracy_score(m2pred, actual)


print("m1 acc", m1acc)
print("m2 acc", m2acc)
# Out:
# m1 acc 0.771428571429
# m2 acc 0.742857142857

# %%
# plot humidity
humidity_df = pd.read_csv("../data/humtemp.csv")


humidity_df.head()
# Out:
#    Unnamed: 0  Temperature  Humidity  Class
# 0           1           45        33      2
# 1           2           27        29      3
# 2           3           40        48      2
# 3           4           40        65      1
# 4           5           38        82      1

# %%
ax = humidity_df.plot.scatter(x="Humidity", y="Temperature", c="Class")
